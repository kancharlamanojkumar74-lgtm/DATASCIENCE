# %% [markdown]
# <a href="https://colab.research.google.com/github/kancharlamanojkumar74-lgtm/DATASCIENCE/blob/main/patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,10):
  for j in range(1,i+1):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********

# %%
for i in range(5,0,-1):
  print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(1,10):
  for j in range(1,i+1):
    print("*",end="")
  print()

# %%
number=[1,2,3,4]
for num in number:
  print(num)
# Out:
# 1
# 2
# 3
# 4

# %%
number=[1,2,3,4]
for num in number:
  print("\nnumber are ",num)
# Out:
# number are  1
#
# number are  2
#
# number are  3
#
# number are  4

# %%
for i in range(3):
  print(f"itreation {i+1}")
# Out:
# itreation 1
# itreation 2
# itreation 3

# %%
count = 1
while count <= 5:
    print(f"count is ",count)
    count += 1
# Out:
# count is  1
# count is  2
# count is  3
# count is  4
# count is  5

# %%
name ="manoj"
age=30
marks=80.09
message=f"hello i am {name}"
print(message)
result=f"sum of two is {age+7}"
print(result)
flow=f"folat value {marks}"
print(flow)
# Out:
# hello i am manoj
# sum of two is 37
# folat value 80.09

# %%
for i in range (1,4):
  for j in range(1,4):
    print(f"{i}*{j}={i*j}",end="\t")

  print()
# Out:
# 1*1=1	1*2=2	1*3=3
# 2*1=2	2*2=4	2*3=6
# 3*1=3	3*2=6	3*3=9

# %%
for i in range(4):
  for j in range(3):
   print("#",end=" ")
  print()
# Out:
# # # #
# # # #
# # # #
# # # #

# %%
for i in range(1,10):
    for j in range(1,10-i):
        print(" ",end="")
    for j in range(1,2*i):
        print("*",end="")
    print()
# Out:
#         *
#        ***
#       *****
#      *******
#     *********
#    ***********
#   *************
#  ***************
# *****************
