# %% [markdown]
# <a href="https://colab.research.google.com/github/kancharlamanojkumar74-lgtm/DATASCIENCE/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def temperature():
  t1=77
  t2=75
  t3=50
  c1=(t1-32)*5/9
  c2=(t2-32)*5/9
  c3=(t3-32)*5/9
  print(c1,c2,c3)
temperature()
# Out:
# 25.0 23.88888888888889 10.0

# %%
def temperature():
  i=int(input("enter a value"))
  c1=(i-32)*5/9
  print(c1)
temperature()
# Out:
# enter a value77
# 25.0

# %%
def temperature(fahren):
    return (fahren - 32) * 5 / 9
print(temperature(77))
print(temperature(75))
print(temperature(50))
# Out:
# 25.0
# 23.88888888888889
# 10.0

# %%
def concat(a,b):
    return a+b
    print(concat(black,white))

# %%
age = 20
print("my age"+str(age))
# Out:
# my age20
