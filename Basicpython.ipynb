# %% [markdown]
# <a href="https://colab.research.google.com/github/kancharlamanojkumar74-lgtm/DATASCIENCE/blob/main/Basicpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3.14
print(type(a))
# Out:
# <class 'float'>

# %%
a=4+3i
print(type(a))
# Out:
#   File "/tmp/ipykernel_5107/3302541183.py", line 1
#     a=4+3i
#         ^
# SyntaxError: invalid decimal literal

# %%
'hello'
'''hello'''
# Out:
# 'hello'

# %%
sentence="""
hi this is manoj
hello gm
how aree u
"""
print(sentence)
# Out:
# hi this is manoj
# hello gm
# how aree u

# %%
import pandas as pd

data = pd.read_csv("Automobile_data (1).csv")
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_163/1143179850.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_csv(r"E:\data sceinece\data sets\Automobile_data (1).csv")
#       4 print(data)
#
# ...

# %%
a="hello world"
print(a[5:])
print(a[2:4])
# Out:
#  world
#
# ll

# %%
a = "hello world"
print(a[-2:-5])
